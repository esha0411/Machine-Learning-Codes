# %% [markdown]
# # **Using Pytesseract for OCR**

# %% [markdown]
# This practical covers the use of python library pytesseract to perform OCR.

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 40 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# ...

# %% [markdown]
# # **Part 1**

# %% [markdown]
# **Reading text from a Single Image file**

# %%
import pytesseract
import shutil
import os
import random
try:
  from PIL import Image
except ImportError:
  import Image
from google.colab.patches import cv2_imshow
import cv2
from matplotlib import pyplot as plt

# %%
# Reading an image
x = "/content/drive/MyDrive/abc.png"
img = cv2.imread(x)
img1 = Image.open(x)

# Potting the image using matplotlib
cv2_imshow(img)
plt.imshow(img1)

# The function image_to_string of pytesseract converts the text in the image into a string.
result = pytesseract.image_to_string(Image.open(x))
print(result)
# Out:
# <PIL.Image.Image image mode=RGB size=455x262 at 0x7F5A5C8DC7D0>
# Image
#
# 1234567890
#
# Results
#
# 1234567890

# %%
y = "/content/drive/MyDrive/french.jpg"
img = cv2.imread(y)
img1 = Image.open(y)
cv2_imshow(img)
plt.imshow(img1)
result1 = pytesseract.image_to_string(Image.open(y))
print(result1)
# Out:
# <PIL.Image.Image image mode=RGB size=1125x707 at 0x7F5A65AFE910>
# En-To change the volume of text speech,
# input a long sentence and adjust the
# volume with the volume button before the
# speech is over.
#
# Fr-Pour modifier le volume de la lecture du
# texte, entrez une longue phrase et ajustez
# le volume avec le bouton volume avant la
# fin du lecture.

# %%
y = "/content/drive/MyDrive/japanese.png"
img = cv2.imread(y)
img1 = Image.open(y)
cv2_imshow(img)
plt.imshow(img1)
result1 = pytesseract.image_to_string(Image.open(y))
print(result1)
# Out:
# <PIL.Image.Image image mode=RGB size=1279x720 at 0x7F5A5C88CDD0>
# CCP 7 IVIT IB

# %%
y = "/content/drive/MyDrive/dutch.png"
img = cv2.imread(y)
img1 = Image.open(y)
cv2_imshow(img)
plt.imshow(img1)
result1 = pytesseract.image_to_string(Image.open(y))
print(result1)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F5A5AB1EE50>
# Lorem ipsum dol¢
#
# Utinam habemus assueverit et est. Eli
# Ex eam nusquam commune. Vis eu ps
# Lorem ipsum dolor sit amet, te quaes
#
# Utinam habemus assueverit et est. Elit pertinacia mea no. At
# Ex eam nusquam commune. Vis eu perpetua interesset. Utrc
# Lorem ipsum dolor sit amet, te quaestio dignissim repudiand.
# Sed ut perspiciatis unde omnis iste natus error sit voluptaten

# %%
y = "/content/drive/MyDrive/noisy.png"
img = cv2.imread(y)
img1 = Image.open(y)
cv2_imshow(img)
plt.imshow(img1)
result1 = pytesseract.image_to_string(Image.open(y))
print(result1)
# Out:
# <PIL.Image.Image image mode=RGB size=410x231 at 0x7F5A5AA4ACD0>
# Tesseract Will
# Fail With Noisy
# Backgrounds

# %%
#very noisy image, tesseract fails
y = "/content/drive/MyDrive/ttt.jpeg"
img = cv2.imread(y)
img1 = Image.open(y)
cv2_imshow(img)
plt.imshow(img1)
result1 = pytesseract.image_to_string(Image.open(y))
print(result1)
# Out:
# <PIL.Image.Image image mode=RGB size=369x373 at 0x7F5A5A9D4BD0>

# %% [markdown]
# # **Part 2**

# %% [markdown]
# **Reading a multi-page PDF using pytesseract**

# %% [markdown]
# To perform this, we need to include another python library pdf2image, we'll use this library to convert the pdf pages into images so that we can ask the pytesseract library to read them.

# %%
# !apt-get install poppler-utils
# !pip install pdf2image
from PIL import Image
import pytesseract
import sys
from pdf2image import convert_from_path
import os


#Step 1 - traverse the whole pdf and create images from the pages of the pdf.


# storing pages of pdf in 'pages' variable
PDF_file = "/content/drive/MyDrive/review.pdf"
pages = convert_from_path(PDF_file, 500)

# taking each page and saving as photo
image_counter = 1

for page in pages:
    filename = "page_"+str(image_counter)+".jpg"
    page.save(filename, 'JPEG')
    image_counter = image_counter + 1

#Step 2 -read the images and then pass them to tesseract to do the OCR


# taking the images and writing it to the output file 
filelimit = image_counter-1
outfile = "/content/drive/MyDrive/Output.txt"

f = open(outfile, "a")

for i in range(1, filelimit + 1):
    filename = "page_"+str(i)+".jpg"
    text = str(((pytesseract.image_to_string(Image.open(filename)))))
    text = text.replace('-\n', '')    
    f.write(text)

with open(outfile,'r') as f:
    for line in f:
        print(line)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-utils is already the newest version (0.62.0-2ubuntu2.12).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# ...
# Review of Real-time Visual Driver Distraction
#
# Detection Algorithms
#
#
#
# ChristerAhlstrom
#
# christer.ahlstrom@vti.se
#
#
#
# Katja Kircher
#
# katja.kircher@vti.se
#
#
#
# Swedish National Road and Transport Research Institute (VT1),
#
# 581 95 Linkoping, Sweden
#
#
#
# ABSTRACT
#
#
#
# Many incidents and crashes can be attributed to driver
#
# distraction, and it is essential to learn how to
#
# detectdistraction in order to develop _ efficient
#
# countermeasures. A number of distraction detection
#
# algorithms have been developed over the years, and the
#
# ...
